# %% [markdown]
# ## Import data

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %%
data_table.disable_dataframe_formatter()

# %%
df_fk = pd.read_excel('/content/drive/MyDrive/Dokumen/Tugas-Tugas/Kuliah/RISET MBKM-STKI/Pemberian Label Manual/FP_Final.xlsx')

# %%
df_fk = df_fk.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-890e2fbfd614> in <cell line: 1>()
# ----> 1 df_fk = df_fk.drop(columns=['Unnamed: 0'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
# ...

# %%
df_fk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3108 entries, 0 to 3107
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   divisions                     3108 non-null   object
#  1   No                            3108 non-null   int64
#  2   title                         3108 non-null   object
#  3   abstract                      2788 non-null   object
#  4   subjects                      3108 non-null   object
#  5   publication                   1310 non-null   object
#  6   publisher                     2275 non-null   object
#  7   date                          2702 non-null   object
#  8   keywords                      3108 non-null   object
#  9   uri                           3108 non-null   object
#  10  fulltext_raw                  3108 non-null   object
#  11  lang                          3108 non-null   object
# ...

# %%
df_fk[['title', 'fokus_riset']]
# Out:
#                                                   title       fokus_riset
# 0     TOKSISITAS METIL METSULFURON HUBUNGANNYA DENGA...  Pangan-Pertanian
# 1     Strategi Keberlanjutan Jasa Air Bersih Berbasi...  Pangan-Pertanian
# 2     Metode Sexing Spermatozoa XY dan Aplikasi Inse...  Pangan-Pertanian
# 3     PENGARUH BAHAN PELLETING TERHADAP PERKECAMBAHA...  Pangan-Pertanian
# 4     PENGENALAN BUNGA KRISAN POTONG DI DESA SUNGAI ...  Pangan-Pertanian
# ...                                                 ...               ...
# 3103            Similarity Dasar-Dasar Budidaya Tanaman  Pangan-Pertanian
# 3104                       Dasar-Dasar Budidaya Tanaman  Pangan-Pertanian
# 3105                 Publikasi LKTI Mahasiswa "Bisikan"               NaN
# 3106     Publikasi LKTI Mahasiswa "Edible Water Bubble"               NaN
# 3107       Publikasi LKTI Mahasiswa "Vegetable Leather"               NaN
#
# [3108 rows x 2 columns]

# %% [markdown]
# ## Cek Ada label apa saja

# %%
topik_riset = {'phew'}

for i in range(len(df_fk['fokus_riset'])):
  topik_riset.add(df_fk['fokus_riset'].iloc[i])

# %%
topik_riset
# Out:
# {'Integrasi Fokus Riset Energi-Energi Baru dan Terbarukan',
#  'Kebencanaan',
#  'Kemaritiman',
#  'Kesehatan-Obat',
#  'Material Maju',
#  'Pangan-Pertanian',
#  'Pertahanan dan Keamanan',
#  'Sosial Humaniora, Seni Budaya, Pendidikan',
#  'Teknologi Informasi dan Komunikasi',
#  nan,
#  'phew'}

# %% [markdown]
# ### Ganti label/Tampilkan judul dengan label tertentu

# %%
temporal = []

for i in range(len(df_fk['fokus_riset'])):
  if df_fk['fokus_riset'].iloc[i] == 'Pangan-Pertanian':
    temporal.append(df_fk.iloc[i])

# %%
temporal = []

for i in range(len(df_fk['fokus_riset'])):
  if pd.isnull(df_fk['fokus_riset'].iloc[i]):
    temporal.append(df_fk.iloc[i])

# %%
len(temporal)
# Out:
# 780

# %%
df_temp = pd.DataFrame(temporal)
df_temp[['title', 'fokus_riset']]
# Out:
#                                                   title  fokus_riset
# 13    Bukti Menerima Hibah Penelitian Total Rp100 ju...          NaN
# 14                 PJOES_Water Quality_Bakri_Yushananta          NaN
# 20    Bukti Korespondesi Jurnal "Financial Feasibili...          NaN
# 37    Pengelolaan kualitas air dengan metode sifon d...          NaN
# 61    PENGARUH INFLASI, PDRB, SUKU BUNGA DAN TENAGA ...          NaN
# ...                                                 ...          ...
# 3097  STUDI KELIMPAHAN DAN SEBARAN TUMBUHAN BERPOTEN...          NaN
# 3100  STRATEGI PENGELOLAAN HUTAN RAKYAT PINANG JAYA ...          NaN
# 3105                 Publikasi LKTI Mahasiswa "Bisikan"          NaN
# 3106     Publikasi LKTI Mahasiswa "Edible Water Bubble"          NaN
# 3107       Publikasi LKTI Mahasiswa "Vegetable Leather"          NaN
#
# [780 rows x 2 columns]

# %%
pd.DataFrame(df_fk[['title','abstract','fokus_riset']].iloc[2839])
# Out:
#                                                           2839
# title        PENGARUH ASAM HUMAT DAN KOMPOS SEBAGAI AMELIOR...
# abstract     Abstrak. Tujuan penelitian ini untuk menguji k...
# fokus_riset                            Pertahanan dan Keamanan

# %% [markdown]
# ## Memberikan label manual

# %%
'Pangan-Pertanian'
'Integrasi Fokus Riset Energi-Energi Baru dan Terbarukan'
'Kesehatan-Obat'
'Transportasi'
'Teknologi Informasi dan Komunikasi'
'Pertahanan dan Keamanan'
'Material Maju'
'Kemaritiman'
'Kebencanaan'
'Sosial Humaniora, Seni Budaya, Pendidikan'
np.nan
# Out:
# 'Sosial Humaniora, Seni Budaya, Pendidikan'

# %%
df_fk['fokus_riset'].iloc[630] = np.nan
# Out:
# <ipython-input-193-78ed4557c340>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fk['fokus_riset'].iloc[630] = np.nan

# %%
df_fk['fokus_riset'].iloc[657] = 'Sosial Humaniora, Seni Budaya, Pendidikan'
# Out:
# <ipython-input-161-42f781edaa49>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fk['fokus_riset'].iloc[657] = 'Sosial Humaniora, Seni Budaya, Pendidikan'

# %%
df_fk['fokus_riset'].iloc[64] = 'Material Maju'
# Out:
# <ipython-input-204-a3e76cb180fe>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fk['fokus_riset'].iloc[64] = 'Material Maju'

# %%
df_fk['fokus_riset'].iloc[1732] = 'Teknologi Informasi dan Komunikasi'
# Out:
# <ipython-input-180-f0e7e66e7583>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fk['fokus_riset'].iloc[1732] = 'Teknologi Informasi dan Komunikasi'

# %%
df_fk['fokus_riset'].iloc[639] = 'Kemaritiman'
# Out:
# <ipython-input-192-8b3ad9665452>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fk['fokus_riset'].iloc[639] = 'Kemaritiman'

# %%
df_fk['fokus_riset'].iloc[120] = 'Pangan-Pertanian'
# Out:
# <ipython-input-205-1f0445a8da48>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fk['fokus_riset'].iloc[120] = 'Pangan-Pertanian'

# %%
for i in range(537, 541) :
  df_fk['fokus_riset'].iloc[i] = 'Pangan-Pertanian'
# Out:
# <ipython-input-142-05dd4b79d718>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fk['fokus_riset'].iloc[i] = 'Pangan-Pertanian'

# %%
label = []

# %%
for i in range(249):
  label.append(df_fk['fokus_riset'].iloc[i])

# %%
import numpy as np

fokus_riset = [
    np.nan,  # 3001
    'Pangan-Pertanian',  # 3002
    'Pangan-Pertanian',  # 3003
    'Pangan-Pertanian',  # 3004
    'Pangan-Pertanian',  # 3005
    'Pangan-Pertanian',  # 3006
    'Pangan-Pertanian',  # 3007
    np.nan,  # 3008
    np.nan,  # 3009
    np.nan,  # 3010
    np.nan,  # 3011
    np.nan,  # 3012
    np.nan,  # 3013
    np.nan,  # 3014
    'Pangan-Pertanian',  # 3015
    np.nan,  # 3016
    'Pangan-Pertanian',  # 3017
    'Pangan-Pertanian',  # 3018
    'Pangan-Pertanian',  # 3019
    'Pangan-Pertanian',  # 3020
    'Pangan-Pertanian',  # 3021
    'Pangan-Pertanian',  # 3022
    'Pangan-Pertanian',  # 3023
    'Pangan-Pertanian',  # 3024
    'Pangan-Pertanian',  # 3025
    'Pangan-Pertanian',  # 3026
    'Pangan-Pertanian',  # 3027
    'Pangan-Pertanian',  # 3028
    'Pangan-Pertanian',  # 3029
    'Pangan-Pertanian',  # 3030
    'Pangan-Pertanian',  # 3031
    'Pangan-Pertanian',  # 3032
    'Pangan-Pertanian',  # 3033
    'Kemaritiman',  # 3034
    'Kemaritiman',  # 3035
    'Kemaritiman',  # 3036
    'Kemaritiman',  # 3037
    'Kemaritiman',  # 3038
    'Kemaritiman',  # 3039
    'Kemaritiman',  # 3040
    'Kemaritiman',  # 3041
    'Pangan-Pertanian',  # 3042
    'Pangan-Pertanian',  # 3043
    'Pangan-Pertanian',  # 3044
    'Pangan-Pertanian',  # 3045
    'Pangan-Pertanian',  # 3046
    np.nan,  # 3047
    'Pangan-Pertanian',  # 3048
    'Pangan-Pertanian',  # 3049
    'Integrasi Fokus Riset Energi-Energi Baru dan Terbarukan',  # 3050
    'Pangan-Pertanian',  # 3051
    'Pangan-Pertanian',  # 3052
    'Pangan-Pertanian',  # 3053
    'Pangan-Pertanian',  # 3054
    'Pangan-Pertanian',  # 3055
    'Pangan-Pertanian',  # 3056
    'Kemaritiman',  # 3057
    'Kemaritiman',  # 3058
    'Sosial Humaniora, Seni Budaya, Pendidikan',  # 3059
    'Pangan-Pertanian',  # 3060
    'Pangan-Pertanian',  # 3061
    'Pangan-Pertanian',  # 3062
    np.nan,  # 3063
    'Pangan-Pertanian',  # 3064
    'Pangan-Pertanian',  # 3065
    'Pangan-Pertanian',  # 3066
    np.nan,  # 3067
    np.nan,  # 3068
    np.nan,  # 3069
    'Pangan-Pertanian',  # 3070
    'Pangan-Pertanian',  # 3071
    'Pangan-Pertanian',  # 3072
    np.nan,  # 3073
    'Pangan-Pertanian',  # 3074
    'Pangan-Pertanian',  # 3075
    np.nan,  # 3076
    'Pangan-Pertanian',  # 3077
    'Pangan-Pertanian',  # 3078
    'Pangan-Pertanian',  # 3079
    'Pangan-Pertanian',  # 3080
    'Pangan-Pertanian',  # 3081
    'Pangan-Pertanian',  # 3082
    'Pangan-Pertanian',  # 3083
    'Pangan-Pertanian',  # 3084
    np.nan,  # 3085
    np.nan,  # 3086
    np.nan,  # 3087
    np.nan,  # 3088
    np.nan,  # 3089
    'Pangan-Pertanian',  # 3090
    'Pangan-Pertanian',  # 3091
    'Pangan-Pertanian',  # 3092
    np.nan,  # 3093
    np.nan,  # 3094
    'Pangan-Pertanian',  # 3095
    'Pangan-Pertanian',  # 3096
    'Pangan-Pertanian',  # 3097
    np.nan,  # 3098
    'Pangan-Pertanian',  # 3099
    'Pangan-Pertanian',  # 3100
    np.nan,  # 3101
    'Pangan-Pertanian',  # 3102
    'Pangan-Pertanian',  # 3103
    'Pangan-Pertanian',  # 3104
    'Pangan-Pertanian',  # 3105
    np.nan,  # 3106
    np.nan,  # 3107
    np.nan,  # 3108
]

# %%
len(fokus_riset)
# Out:
# 108

# %%
for i in fokus_riset:
  label.append(i)

# %%
len(label)
# Out:
# 2108

# %%
label

# %%
for i in range(len(label)):
  df_fk['fokus_riset'].iloc[1000+i] = label[i]

# %%
df_fk.to_excel('/content/drive/MyDrive/Dokumen/Tugas-Tugas/Kuliah/RISET MBKM-STKI/Pemberian Label Manual/FP_Final_CK4.xlsx', index=False)

# %% [markdown]
# ## Mencari URL Jurnal (skip)

# %%
url_jurnal = []

for i in range(len(df_fk['title'])):
  temp = df_fk['title'].iloc[i]
  status_pencarian = False

  for j in range(len(df_ori['title'])):
    if status_pencarian == False:
      if df_ori['title'].iloc[j] == temp:
        url_jurnal.append(df_ori['uri'].iloc[j])
        status_pencarian = True
        break
      else:
        status_pencarian = False

  if status_pencarian == False:
    url_jurnal.append(np.nan)

df_fk['url'] = url_jurnal

# %%
df_fk[['title','fokus_riset','url']]
# Out:
#                                                   title  \
# 0          Modul Pelatian TOT Bagi Dosen Home Based DLP
# 1     Peer Review : Faktor Risiko Anemia pada Pender...
# 2     Peer Review : Pengaruh Komorbid terhadap Terja...
# 3     Peer Review : Pengaruh Konsumsi Kafein pada Si...
# 4                       Mekanisme Kerja Obat Anti Batuk
# ...                                                 ...
# 1024    COVID-19 Dengan Gagal Ginjal (Literature Review
# 1025  EVALUASI HASIL TATALAKSANA LASER FOTOKOAGOLASI...
# 1026            ASBESTOSIS, DIAGNOSIS DAN PENCEGAHANNYA
# 1027  Laporan Kasus: Bronkiektasis Terinfeksi disert...
# 1028  Gambaran Profil Lipid pada Pasien Infark Mioka...
#
#                                     fokus_riset  \
# 0     Sosial Humaniora, Seni Budaya, Pendidikan
# 1                                Kesehatan-Obat
# 2                                Kesehatan-Obat
# 3                                Kesehatan-Obat
# ...
