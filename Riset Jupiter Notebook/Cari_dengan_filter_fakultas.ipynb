# %%
import pandas as pd
import ast

# %%
df = pd.read_csv('/content/drive/MyDrive/Dokumen/Tugas-Tugas/Kuliah/RISET MBKM-STKI/Preprocessing/df_final.csv')

# %%
df.fillna("", inplace=True)

# %%
df[['divisions','title']]
# Out:
#         divisions                                              title
# 0        ['FP20']  TOKSISITAS METIL METSULFURON HUBUNGANNYA DENGA...
# 1      ['FKIP24']  Media Pembelajaran Digital sebagai Sumber Bela...
# 2         ['FP1']  Strategi Keberlanjutan Jasa Air Bersih Berbasi...
# 3        ['FP17']  Metode Sexing Spermatozoa XY dan Aplikasi Inse...
# 4        ['FP25']  PENGARUH BAHAN PELLETING TERHADAP PERKECAMBAHA...
# ...           ...                                                ...
# 15862     ['FH3']  Perlindungan Terhadap Korban Perang \r\ndalam ...
# 15863     ['FH3']  HAK KEKAYAAN INTELEKTUAL BAGI PEKERJA SENI DI ...
# 15864     ['FT1']  Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15865              Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15866              Similiaritu_Analisis Struktur Patahan Daerah S...
#
# [15867 rows x 2 columns]

# %%
ast.literal_eval(df['divisions'].iloc[100])
# Out:
# ['FISIP6']

# %%
ast.literal_eval('[]')
# Out:
# []

# %%
list1 = [1, 2, 3, 4, 5]
list2 = []

set_list2 = set(list2)

for a in list1:
    if a in set_list2:
        print("Ada")
    else:
        print("Tidak Ada")
# Out:
# Tidak Ada
# Tidak Ada
# Tidak Ada
# Tidak Ada
# Tidak Ada

# %%
new_divisions = []
for i in range(len(df['divisions'])):
  try:
    new_divisions.append(ast.literal_eval(df['divisions'].iloc[i]))
  except:
    new_divisions.append(ast.literal_eval('[]'))

# %%
df['new_divisions'] = new_divisions

# %%
df[['divisions','title','new_divisions']]
# Out:
#         divisions                                              title  \
# 0        ['FP20']  TOKSISITAS METIL METSULFURON HUBUNGANNYA DENGA...
# 1      ['FKIP24']  Media Pembelajaran Digital sebagai Sumber Bela...
# 2         ['FP1']  Strategi Keberlanjutan Jasa Air Bersih Berbasi...
# 3        ['FP17']  Metode Sexing Spermatozoa XY dan Aplikasi Inse...
# 4        ['FP25']  PENGARUH BAHAN PELLETING TERHADAP PERKECAMBAHA...
# ...           ...                                                ...
# 15862     ['FH3']  Perlindungan Terhadap Korban Perang \r\ndalam ...
# 15863     ['FH3']  HAK KEKAYAAN INTELEKTUAL BAGI PEKERJA SENI DI ...
# 15864     ['FT1']  Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15865              Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15866              Similiaritu_Analisis Struktur Patahan Daerah S...
#
#       new_divisions
# 0            [FP20]
# 1          [FKIP24]
# 2             [FP1]
# 3            [FP17]
# 4            [FP25]
# ...

# %%
for i in range(len(df)):
  if len(df['new_divisions'].iloc[i]) > 2:
    print(i)
# Out:
# 6973
# 8322
# 8323
# 8344

# %%
fakultas = df['new_divisions']

# %%
fakultas.to_list()

# %%
import re

def pisahkan_kata(kata):
    hasil = re.sub(r'\d', '', kata)
    return hasil

# %%
new_fakultas = []
for i in range(len(df)):
  temp = df['new_divisions'].iloc[i]
  temp2 = []
  for j in range(len(temp)):
    temp2.append(pisahkan_kata(temp[j]))
  new_fakultas.append(temp2)

# %%
new_fakultas

# %%
df['pra_fakultas'] = new_fakultas

# %%
df[['divisions','title','new_divisions','pra_fakultas']]
# Out:
#         divisions                                              title  \
# 0        ['FP20']  TOKSISITAS METIL METSULFURON HUBUNGANNYA DENGA...
# 1      ['FKIP24']  Media Pembelajaran Digital sebagai Sumber Bela...
# 2         ['FP1']  Strategi Keberlanjutan Jasa Air Bersih Berbasi...
# 3        ['FP17']  Metode Sexing Spermatozoa XY dan Aplikasi Inse...
# 4        ['FP25']  PENGARUH BAHAN PELLETING TERHADAP PERKECAMBAHA...
# ...           ...                                                ...
# 15862     ['FH3']  Perlindungan Terhadap Korban Perang \r\ndalam ...
# 15863     ['FH3']  HAK KEKAYAAN INTELEKTUAL BAGI PEKERJA SENI DI ...
# 15864     ['FT1']  Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15865              Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15866              Similiaritu_Analisis Struktur Patahan Daerah S...
#
#       new_divisions pra_fakultas
# 0            [FP20]         [FP]
# 1          [FKIP24]       [FKIP]
# 2             [FP1]         [FP]
# ...

# %%
df_hasil = []
for i in range(len(df)):
  if 'FK' in df['pra_fakultas'].iloc[i]:
    df_hasil.append(df.iloc[i])

# %%
df_hasil = pd.DataFrame(df_hasil)

# %%
df_hasil[['title','pra_fakultas']]
# Out:
#                                                    title pra_fakultas
# 25       COVID-19 Dengan Gagal Ginjal (Literature Review         [FK]
# 328    EVALUASI HASIL TATALAKSANA LASER FOTOKOAGOLASI...         [FK]
# 345              ASBESTOSIS, DIAGNOSIS DAN PENCEGAHANNYA         [FK]
# 346    Laporan Kasus: Bronkiektasis Terinfeksi disert...         [FK]
# 347    Gambaran Profil Lipid pada Pasien Infark Mioka...         [FK]
# ...                                                  ...          ...
# 15784  Bimbingan dan Dukungan Mahasiswa, Sebuah Ilust...         [FK]
# 15793  Similarity Efek Pemberian Minyak Buah Merah pa...         [FK]
# 15795  PENCEGAHAN STUNTING MELALUI PEMBERDAYAAN MASYA...         [FK]
# 15816  PEMBERDAYAAN SEKOLAH DALAM PENERAPAN PROTOKOL ...         [FK]
# 15817  FAKTOR FAKTOR YANG BERHUBUNGAN DENGAN PERKEMBA...         [FK]
#
# [1129 rows x 2 columns]
