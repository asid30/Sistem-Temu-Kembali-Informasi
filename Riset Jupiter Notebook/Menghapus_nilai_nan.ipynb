# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel(r'D:\TEST Codingan\Sistem-Temu-Kembali-Informasi\Riset Jupiter Notebook\Data\df_final.xlsx')
df = df.drop(columns='Unnamed: 0')
df
# Out:
#         divisions                                              title  \
# 0        ['FP20']  TOKSISITAS METIL METSULFURON HUBUNGANNYA DENGA...
# 1      ['FKIP24']  Media Pembelajaran Digital sebagai Sumber Bela...
# 2         ['FP1']  Strategi Keberlanjutan Jasa Air Bersih Berbasi...
# 3        ['FP17']  Metode Sexing Spermatozoa XY dan Aplikasi Inse...
# 4        ['FP25']  PENGARUH BAHAN PELLETING TERHADAP PERKECAMBAHA...
# ...           ...                                                ...
# 15862     ['FH3']  Perlindungan Terhadap Korban Perang \ndalam Pe...
# 15863     ['FH3']  HAK KEKAYAAN INTELEKTUAL BAGI PEKERJA SENI DI ...
# 15864     ['FT1']  Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15865         NaN  Analisis Struktur Patahan Daerah Suoh Mengguna...
# 15866         NaN  Similiaritu_Analisis Struktur Patahan Daerah S...
#
#                                                 abstract      subjects  \
# 0      Metil metsulfuron merupakan senyawa aktif yang...  ['Q1', 'SH']
# 1      Kegiatan pembelajaran siswa SMA dan SMK mutlak...        ['LA']
# 2      Persoalan penyediaan jasa air bersih merupakan...        ['S1']
# 3                                                    NaN        ['SF']
# 4      Bawang merah merupakan komoditas pertanian pen...        ['S1']
# ...                                                  ...           ...
# 15862  Konflik bersenjata hingga kini masih menjadi p...        ['K1']
# 15863  Dalam perkembangannya, karya cipta hasil kreas...        ['K1']
# 15864  Suoh merupakan daerah tektonik aktif yang meng...        ['TN']
# 15865                                                NaN        ['TN']
# 15866                                                NaN        ['TN']
#
#                                              publication  \
# 0                                                    NaN
# 1                      EDUKATIF : JURNAL ILMU PENDIDIKAN
# 2                                                    NaN
# 3                                                    NaN
# 4                                     Jurnal Agrotropika
# ...                                                  ...
# 15862                                                NaN
# 15863  Jurnal Pengabdian kepada Masyarakat Sakai Semb...
# 15864                     POSITRON Berkala Ilmiah Fisika
# 15865                                                NaN
# 15866                                                NaN
#
#                                                publisher  \
# 0      Jurusan Perikanan dan Kelautan, Fakultas Perta...
# 1                   Universitas Pahlawan Tuanku Tambusai
# 2                               LPPM Universitas Lampung
# 3                                         Kusuma Dokumen
# 4                                                    NaN
# ...                                                  ...
# 15862                                               ICRC
# 15863  Lembaga Penelitian dan Pengabdian kepada Masya...
# 15864                                                NaN
# 15865  Jurusan Teknik Geofisika, Fakultas Teknik, Uni...
# 15866  Jurusan Fisika, Fakultas Matematika dan Ilmu P...
#
#                                                 creators                 date  \
# 0      [{'name': {'honourific': None, 'lineage': None...  2024-01-15 00:00:00
# 1      [{'id': 'suparman.arif@fkip.unila.ac.id', 'nam...  2023-02-28 00:00:00
# 2      [{'name': {'given': 'Zainal', 'lineage': None,...  2023-09-19 00:00:00
# 3      [{'name': {'honourific': None, 'family': 'Adhi...                 2023
# 4      [{'id': 'agustiansyah.1972@fp.unila.ac.id', 'n...                 2023
# ...                                                  ...                  ...
# 15862  [{'id': None, 'name': {'honourific': None, 'gi...                  NaN
# 15863  [{'name': {'lineage': None, 'given': 'yunita m...                  NaN
# 15864  [{'name': {'given': 'ahmad', 'lineage': None, ...                  NaN
# 15865  [{'name': {'honourific': None, 'family': 'zaen...                  NaN
# 15866  [{'id': 'ahmad.zaenudin@eng.unila.ac.id', 'nam...                  NaN
#
#                                                 keywords  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                    Bawang merah, Benih, Pelleting, TSS
# ...                                                  ...
# 15862  Korban Perang, Hukum Humaniter Internasional, HAM
# 15863                                                NaN
# 15864                                                NaN
# 15865                                                NaN
# 15866                                                NaN
#
#                                                      uri  \
# 0      http://repository.lppm.unila.ac.id/id/eprint/4...
# 1      http://repository.lppm.unila.ac.id/id/eprint/4...
# 2      http://repository.lppm.unila.ac.id/id/eprint/5...
# 3      http://repository.lppm.unila.ac.id/id/eprint/5...
# 4      http://repository.lppm.unila.ac.id/id/eprint/5...
# ...                                                  ...
# 15862  http://repository.lppm.unila.ac.id/id/eprint/2...
# 15863  http://repository.lppm.unila.ac.id/id/eprint/2...
# 15864  http://repository.lppm.unila.ac.id/id/eprint/3...
# 15865  http://repository.lppm.unila.ac.id/id/eprint/4...
# 15866  http://repository.lppm.unila.ac.id/id/eprint/3...
#
#                                             new_abstract  \
# 0      Metil metsulfuron merupakan senyawa aktif yang...
# 1      Kegiatan pembelajaran siswa SMA dan SMK mutlak...
# 2      Persoalan penyediaan jasa air bersih merupakan...
# 3                                                    NaN
# 4      Bawang merah merupakan komoditas pertanian pen...
# ...                                                  ...
# 15862  Konflik bersenjata hingga kini masih menjadi p...
# 15863  Dalam perkembangannya, karya cipta hasil kreas...
# 15864  Suoh merupakan daerah tektonik aktif yang meng...
# 15865                                                NaN
# 15866                                                NaN
#
#                                                 text_raw language  \
# 0      TOKSISITAS METIL METSULFURON HUBUNGANNYA DENGA...       id
# 1      Media Pembelajaran Digital sebagai Sumber Bela...       id
# 2      Strategi Keberlanjutan Jasa Air Bersih Berbasi...       id
# 3      Metode Sexing Spermatozoa XY dan Aplikasi Inse...       id
# 4      PENGARUH BAHAN PELLETING TERHADAP PERKECAMBAHA...       id
# ...                                                  ...      ...
# 15862  Perlindungan Terhadap Korban Perang \ndalam Pe...       id
# 15863  HAK KEKAYAAN INTELEKTUAL BAGI PEKERJA SENI DI ...       id
# 15864  Analisis Struktur Patahan Daerah Suoh Mengguna...       id
# 15865  Analisis Struktur Patahan Daerah Suoh Mengguna...       id
# 15866  Similiaritu_Analisis Struktur Patahan Daerah S...       id
#
#              language_accuracy  \
# 0      [id:0.9999985998246005]
# 1      [id:0.9999984649495912]
# 2      [id:0.9999969177170068]
# 3       [id:0.999998385833847]
# 4      [id:0.9999981965987415]
# ...                        ...
# 15862  [id:0.9999968843606628]
# 15863  [id:0.9999969864056528]
# 15864  [id:0.9999965565270186]
# 15865   [id:0.999997868885034]
# 15866  [id:0.9999966342530218]
#
#                                                 fulltext  \
# 0      toksisitas metil metsulfuron hubungannya denga...
# 1      media pembelajaran digital sebagai sumber bela...
# 2      strategi keberlanjutan jasa air bersih berbasi...
# 3      metode sexing spermatozoa xy dan aplikasi inse...
# 4      pengaruh bahan pelleting terhadap perkecambaha...
# ...                                                  ...
# 15862  perlindungan terhadap korban perang dalam pene...
# 15863  hak kekayaan intelektual bagi pekerja seni di ...
# 15864  analisis struktur patahan daerah suoh mengguna...
# 15865  analisis struktur patahan daerah suoh mengguna...
# 15866  similiaritu analisis struktur patahan daerah s...
#
#                                        fulltext_stopword  \
# 0      toksisitas metil metsulfuron hubungannya masku...
# 1      media pembelajaran digital sumber belajar maha...
# 2      strategi jasa air bersih berbasis masyarakat k...
# 3      metode sexing spermatozoa xy aplikasi insemina...
# 4      pengaruh bahan pelleting perkecambahan benih b...
# ...                                                  ...
# 15862  perlindungan korban perang penegakan hukum hum...
# 15863  hak kekayaan intelektual pekerja seni sanggar ...
# 15864  analisis struktur patahan daerah suoh metode g...
# 15865  analisis struktur patahan daerah suoh metode g...
# 15866  similiaritu analisis struktur patahan daerah s...
#
#                                             text_stemmed
# 0      toksisitas metil metsulfuron hubung maskulinit...
# 1      media ajar digital sumber ajar mahasiswa didik...
# 2      strategi jasa air bersih bas masyarakat kawasa...
# 3      metode sexing spermatozoa xy aplikasi insemina...
# 4      pengaruh bahan pelleting kecambah benih bawang...
# ...                                                  ...
# 15862  lindung korban perang tega hukum humaniter int...
# 15863  hak kaya intelektual kerja seni sanggar tari g...
# 15864  analisis struktur patah daerah suoh metode gay...
# 15865  analisis struktur patah daerah suoh metode gay...
# 15866  similiaritu analisis struktur patah daerah suo...
#
# [15867 rows x 17 columns]

# %%
def hapus_nan(DataFrame):
    DataFrame.fillna("", inplace=True) 
    return DataFrame
